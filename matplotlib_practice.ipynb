# %%
# Import dependencies.
import matplotlib.pyplot as plt
matplotlib.__version__
# Out:
# '3.4.3'

# %%
# use print function to check the version
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.4.3

# %%
#To make sure our plots are displayed inline within the Jupyter Notebook directly below the code cell that produced it
# %matplotlib inline

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
y1_axis = [15.02, 28.24, 44.20, 40.42, 38.34, 36.04, 49.82, 16.56, 19.85, 37.90, 29.71, 29.09]

# %%
plt.plot(x_axis,y_axis)

# %%
# object oriented plot
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
fig,ax=plt.subplots()
ax.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
#To create a quick graph using the object-oriented interface method, use the following two lines:
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot using plt.show()
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 55)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
plt.figure(figsize=(8, 5))
#plt.subplots(figsize=(8, 5)) 
plt.plot(x_axis, y_axis, label='Boston', color="Green", marker="*",linewidth=2)
plt.plot(x_axis, y1_axis, label='DC', color="Blue", marker="*",linewidth=2)
plt.xlabel("Date")
plt.ylabel("Fare in($)")
plt.xlim(0,11)
plt.ylim(0,55)
plt.title("PyBer Fare by Month")
plt.grid()
plt.legend()

# %%
#Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# bar chart
plt.bar(x_axis,y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis,color="magenta", label="Boston")
plt.xlabel("Date")
plt.ylabel("fare in ($)")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.legend()

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot with opposite axises
plt.barh(y_axis, x_axis,color="magenta", label="Boston")
plt.xlabel("Date")
plt.ylabel("fare in ($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis,color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
ax = plt.axes()
ax.bar(x_axis, y_axis,color="k", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt() with opposite axises
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill Drill
plt.scatter(y_axis, x_axis, marker='x', c='r', label='Chigago')

plt.ylabel("Date")
plt.xlabel("fare in ($)")
plt.title("PyBer Fare by Month")
plt.xlim(0,50)
plt.gca().invert_yaxis()

plt.legend()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# bubles using for loop
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# bubles with list expresion inside
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# object oriented method
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# bubles
import numpy as np

fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, c='xkcd:sky blue',  s=[i * 3 for i in y_axis], alpha=0.2,edgecolor='black', linewidth=2)
plt.ylabel("Date")
plt.xlabel("Fare in ($)")
plt.title("PyBer Fare by Month")
plt.xlim(0,50)
plt.gca().invert_yaxis()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
# pie chart
explode=[0,0,0,0,0,0,0.2,0,0,0,0,0]
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
plt.subplots(figsize=(8, 8))
plt.pie(y_axis, labels=x_axis,autopct="%1.1f%%", explode=explode)
plt.show()

# %%
# Creating color parameters
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen",
          "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
 
# Wedge properties
wp = { 'linewidth' : 1.5, 'edgecolor' : "black" }
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis,  shadow = True, explode=explode, startangle = 90, colors=colors, wedgeprops = wp)
plt.show()

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#Add Error Bars to a Bar Chart
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()

# %%
#T_T100_MARKET_ALL_CARRIER
import pandas as pd
df_load = "Resources/T_T100_MARKET_ALL_CARRIER.csv"
df = pd.read_csv(df_load )
df
# Out:
#        UNIQUE_CARRIER          UNIQUE_CARRIER_NAME  ORIGIN_AIRPORT_ID ORIGIN  \
# 0                 02Q                Titan Airways              13303    MIA
# 1                 02Q                Titan Airways              14210    POS
# 2                 02Q                Titan Airways              13303    MIA
# 3                 02Q                Titan Airways              14210    POS
# 4                 02Q                Titan Airways              13303    MIA
# ...               ...                          ...                ...    ...
# 216370             ZW  Air Wisconsin Airlines Corp              10980    CHA
# 216371             ZW  Air Wisconsin Airlines Corp              11612    EVV
# 216372             ZW  Air Wisconsin Airlines Corp              12217    HSV
# 216373             ZW  Air Wisconsin Airlines Corp              12217    HSV
# 216374             ZW  Air Wisconsin Airlines Corp              12217    HSV
#
#         DEST_AIRPORT_ID DEST  MONTH
# 0                 14210  POS      5
# 1                 13303  MIA      5
# 2                 14210  POS      7
# 3                 13303  MIA      7
# 4                 14210  POS      3
# ...                 ...  ...    ...
# 216370            13930  ORD      7
# 216371            13930  ORD      7
# 216372            13930  ORD      7
# 216373            14574  ROA      7
# 216374            12264  IAD      7
#
# [216375 rows x 7 columns]

# %%
pivot = df.pivot_table(index='DEST',columns='UNIQUE_CARRIER_NAME', 
                       values='DEST_AIRPORT_ID',aggfunc='sum',
                       margins=True).sort_values('All', ascending=False)
pivot.head(10)
# Out:
# UNIQUE_CARRIER_NAME  40-Mile Air  ABS JETS A.S  ABSA-Aerolinhas Brasileiras  \
# DEST
# All                    1539840.0      157531.0                    2268731.0
# ORD                          NaN           NaN                          NaN
# LAX                          NaN           NaN                          NaN
# MIA                          NaN           NaN                     638544.0
# DEN                          NaN           NaN                          NaN
# DFW                          NaN           NaN                          NaN
# IAH                          NaN           NaN                          NaN
# PHX                          NaN           NaN                          NaN
# ATL                          NaN           NaN                          NaN
# PHL                          NaN           NaN                          NaN
#
# UNIQUE_CARRIER_NAME  ABX Air Inc  ACM AIR CHARTER GmbH  ADVANCED AIR, LLC  \
# DEST
# All                   10180351.0              169021.0         16424984.0
# ORD                     445760.0                   NaN                NaN
# LAX                      64460.0                   NaN           193380.0
# MIA                     425696.0                   NaN                NaN
# DEN                     271008.0                   NaN                NaN
# DFW                      45192.0                   NaN                NaN
# IAH                      36798.0                   NaN                NaN
# PHX                     268033.0                   NaN           479638.0
# ATL                     197543.0                   NaN                NaN
# PHL                      84600.0                   NaN                NaN
#
# UNIQUE_CARRIER_NAME  Acropolis Aviation Ltd.  Aer Lingus Plc  AeroLogic GmbH  \
# DEST
# All                                  87889.0        690304.0       2513311.0
# ORD                                      NaN        125370.0        139300.0
# LAX                                  12892.0             NaN        244948.0
# MIA                                      NaN             NaN             NaN
# DEN                                      NaN             NaN             NaN
# DFW                                      NaN             NaN         56490.0
# IAH                                      NaN             NaN        110394.0
# PHX                                      NaN             NaN             NaN
# ATL                                      NaN             NaN         93573.0
# PHL                                      NaN             NaN             NaN
#
# UNIQUE_CARRIER_NAME  Aeroenlaces Nacionales, S.A. de C.V. d/b/a VivaAerobus  \
# DEST
# All                                                          5076215.0
# ORD                                                           306460.0
# LAX                                                           270732.0
# MIA                                                           106424.0
# DEN                                                                NaN
# DFW                                                           248556.0
# IAH                                                           404778.0
# PHX                                                                NaN
# ATL                                                                NaN
# PHL                                                                NaN
#
# UNIQUE_CARRIER_NAME  ...  Vuela Aviacion, S.A.  WAMOS AIR SA   Warbelow  \
# DEST                 ...
# All                  ...              877638.0      163652.0  4894121.0
# ORD                  ...                   NaN           NaN        NaN
# LAX                  ...              232056.0           NaN        NaN
# MIA                  ...                   NaN       26606.0        NaN
# DEN                  ...                   NaN           NaN        NaN
# DFW                  ...                   NaN           NaN        NaN
# IAH                  ...                   NaN       12266.0        NaN
# PHX                  ...                   NaN           NaN        NaN
# ATL                  ...                   NaN           NaN        NaN
# PHL                  ...                   NaN           NaN        NaN
#
# UNIQUE_CARRIER_NAME  Western Air Charter, Inc.  d/b/a  Jet Edge  \
# DEST
# All                                                  89209368.0
# ORD                                                     69650.0
# LAX                                                    915332.0
# MIA                                                    438999.0
# DEN                                                     56460.0
# DFW                                                     67788.0
# IAH                                                     49064.0
# PHX                                                    282140.0
# ATL                                                     93573.0
# PHL                                                    564000.0
#
# UNIQUE_CARRIER_NAME  Western Global    Westjet  Wright Air Service  \
# DEST
# All                       6959103.0  2598697.0          15639381.0
# ORD                        473620.0        NaN                 NaN
# LAX                        915332.0   116028.0                 NaN
# MIA                             NaN        NaN                 NaN
# DEN                             NaN        NaN                 NaN
# DFW                         11298.0        NaN                 NaN
# IAH                             NaN    12266.0                 NaN
# PHX                         42321.0   141070.0                 NaN
# ATL                             NaN    31191.0                 NaN
# PHL                             NaN        NaN                 NaN
#
# UNIQUE_CARRIER_NAME  Xiamen Airlines Co., Ltd.  ZIPAIR Tokyo Inc.         All
# DEST
# All                                   649173.0           103668.0  2773598527
# ORD                                        NaN                NaN    90266400
# LAX                                   296516.0                NaN    61146756
# MIA                                        NaN                NaN    58599715
# DEN                                        NaN                NaN    49097616
# DFW                                        NaN                NaN    46479972
# IAH                                        NaN                NaN    42906468
# PHX                                        NaN                NaN    41460473
# ATL                                        NaN                NaN    40298772
# PHL                                        NaN                NaN    39324900
#
# [10 rows x 263 columns]

# %%
 Few=df.loc["ORD":"ATL"]
Few
# Out:
# Empty DataFrame
# Columns: [UNIQUE_CARRIER, UNIQUE_CARRIER_NAME, ORIGIN_AIRPORT_ID, ORIGIN, DEST_AIRPORT_ID, DEST, MONTH]
# Index: []

# %%
pivot[Few.sort_index().index]
# Out:
# Empty DataFrame
# Columns: []
# Index: [All, ORD, LAX, MIA, DEN, DFW, IAH, PHX, ATL, PHL, SEA, JFK, LAS, MCO, MSP, EWR, SFO, CLT, FLL, SLC, IAD, MEM, TPA, CVG, SDF, ANC, DTW, BOS, PDX, IND, SAN, STL, BNA, OAK, SAT, RDU, AUS, PIT, SJU, DCA, BWI, ONT, SJC, LGA, RSW, MDW, MSY, MCI, SMF, SNA, TEB, HOU, HNL, VNY, RNO, MKE, CLE, DAL, PBI, JAX, OMA, BET, CMH, SRQ, RIC, YYZ, HPN, FAI, CHS, TUL, OKC, ORF, SAV, MYR, ICN, SFB, ELP, CUN, BDL, PVD, RFD, TUS, BUF, GEG, PIE, OGG, MEX, BOI, BUR, ABQ, PNS, GPT, GRR, SYR, VPS, GSO, PWM, LGB, SJD, GSP, ...]
#
# [1831 rows x 0 columns]
